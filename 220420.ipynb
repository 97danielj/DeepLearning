# %%
from sklearn.datasets import *
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = sns.load_dataset('titanic')

# %%
df.isnull().sum()/len(df)*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df[df['age'].notnull()].groupby(['sex'])['age'].mean()
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
df.loc[61,'embarked']='S'
df.loc[829,'Embarked']='S'
df.isnull().sum()/len(df)*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.112233
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# Embarked       99.887767
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     890 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  Embarked     1 non-null      object
# dtypes: bool(2), category(2), float64(2), int64(4), object(6)
# memory usage: 87.6+ KB

# %%
범주형 = ['pclass','who','sex','embark_town']
숫자형 = ['age','sibsp','parch','fare']

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone Embarked
# 0      man        True  NaN  Southampton    no  False      NaN
# 1    woman       False    C    Cherbourg   yes  False      NaN
# 2    woman       False  NaN  Southampton   yes   True      NaN
# 3    woman       False    C  Southampton   yes  False      NaN
# 4      man        True  NaN  Southampton    no   True      NaN
# ..     ...         ...  ...          ...   ...    ...      ...
# 886    man        True  NaN  Southampton    no   True      NaN
# 887  woman       False    B  Southampton   yes   True      NaN
# 888  woman       False  NaN  Southampton    no  False      NaN
# 889    man        True    C    Cherbourg   yes   True      NaN
# 890    man        True  NaN   Queenstown    no   True      NaN
#
# [891 rows x 16 columns]

# %%
for i in 범주형:
    df[i] = df[i].astype(object)

# %%
def f(ldf, rdf, on, how='inner', index=None ):
    if index is True:
        return pd.merge(ldf, rdf,how=how, left_index=True, right_index=True)
    else:
        return pd.merge(ldf, rdf,how=how, on=on)

# %%
import pandas as pd
one_hot_df=f(df,pd.get_dummies(df['sex'],prefix='sex'),on=None, index=True)

# %%
one_hot_df
# Out:
#      survived pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0      3    male  22.0      1      0   7.2500        S   Third
# 1           1      1  female  38.0      1      0  71.2833        C   First
# 2           1      3  female  26.0      0      0   7.9250        S   Third
# 3           1      1  female  35.0      1      0  53.1000        S   First
# 4           0      3    male  35.0      0      0   8.0500        S   Third
# ..        ...    ...     ...   ...    ...    ...      ...      ...     ...
# 886         0      2    male  27.0      0      0  13.0000        S  Second
# 887         1      1  female  19.0      0      0  30.0000        S   First
# 888         0      3  female   NaN      1      2  23.4500        S   Third
# 889         1      1    male  26.0      0      0  30.0000        C   First
# 890         0      3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone Embarked  sex_female  \
# 0      man        True  NaN  Southampton    no  False      NaN           0
# 1    woman       False    C    Cherbourg   yes  False      NaN           1
# 2    woman       False  NaN  Southampton   yes   True      NaN           1
# 3    woman       False    C  Southampton   yes  False      NaN           1
# 4      man        True  NaN  Southampton    no   True      NaN           0
# ..     ...         ...  ...          ...   ...    ...      ...         ...
# 886    man        True  NaN  Southampton    no   True      NaN           0
# 887  woman       False    B  Southampton   yes   True      NaN           1
# 888  woman       False  NaN  Southampton    no  False      NaN           1
# 889    man        True    C    Cherbourg   yes   True      NaN           0
# 890    man        True  NaN   Queenstown    no   True      NaN           0
#
#      sex_male
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1
# ..        ...
# 886         1
# 887         0
# 888         0
# 889         1
# 890         1
#
# [891 rows x 18 columns]

# %%
X = pd.DataFrame(data,columns=['D_length','D_weight'])
Y = np.array(Y['y'])
np_Y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10920/2915821196.py in <module>
# ----> 1 X = pd.DataFrame(data,columns=['D_length','D_weight'])
#       2 Y = np.array(Y['y'])
#       3 np_Y
#
# NameError: name 'data' is not defined

# %%
np.random.seed(10)
ck=np.arange(49)
np.random.shuffle(ck)
ck
# Out:
# array([37, 23, 43, 41, 46, 20,  3, 30,  7,  6, 38,  2, 39, 32, 10, 21, 35,
#        27, 18, 31,  1, 12, 34, 44, 26,  5, 13, 22, 19, 17, 14,  4, 40, 33,
#        24, 11, 16, 47, 45, 48,  8, 42, 29, 25, 28,  0, 15, 36,  9])
